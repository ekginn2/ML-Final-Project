# %%
import pandas as pd

# %%
#take a look at cleaner csv
hha_df="../datasets/Medicare_Home_Health_Agency Data 2013-2016.csv"
hha_df = pd.read_csv(hha_df)
hha_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (36,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Year  Provider ID                    Agency Name         Street Address  \
# 0  2016        17008     JEFFERSON COUNTY HOME CARE  2201 ARLINGTON AVENUE
# 1  2016        17009  ALACARE HOME HEALTH & HOSPICE        2970 LORNA ROAD
# 2  2016        17013        GENTIVA HEALTH SERVICES       1239 RUCKER BLVD
# 3  2016        17014           AMEDISYS HOME HEALTH      68278 MAIN STREET
# 4  2016        17016     SOUTHEAST ALABAMA HOMECARE      804 GLOVER AVENUE
#
#            City State  Zip Code Total Episodes (non-LUPA)  \
# 0      BESSEMER    AL     35020                       133
# 1    BIRMINGHAM    AL     35216                     12879
# 2    ENTERPRISE    AL     36330                      1236
# ...

# %%
#take a look at cleaner csv
cleaner_hha_df='../datasets/cleaner_hha_df.csv'
cleaner_hha_df = pd.read_csv(cleaner_hha_df)
cleaner_hha_df.head()
# Out:
#    Unnamed: 0  Year  Provider ID Agency Name  Street Address          City  \
# 0           0  2016        17008           0               0      BESSEMER
# 1           1  2016        17009           0               0    BIRMINGHAM
# 2           2  2016        17013           0               0    ENTERPRISE
# 3           3  2016        17014           0               0  BLOUNTSVILLE
# 4           4  2016        17016           0               0    ENTERPRISE
#
#   State  Zip Code  Total Episodes (non-LUPA)  \
# 0    AL     35020                        133
# 1    AL     35216                      12879
# 2    AL     36330                       1236
# 3    AL     35031                        685
# 4    AL     36330                        685
#
#    Distinct Beneficiaries (non-LUPA)        ...         \
# 0                               54.0        ...
# 1                             6616.0        ...
# 2                              612.0        ...
# ...

# %%
cleaner_hha_df['Provider ID']
# Out:
# 0         17008
# 1         17009
# 2         17013
# 3         17014
# 4         17016
# 5         17018
# 6         17020
# 7         17024
# 8         17025
# 9         17026
# 10        17027
# 11        17028
# 12        17034
# 13        17035
# 14        17037
# 15        17039
# 16        17041
# 17        17048
# 18        17050
# 19        17051
# 20        17052
# 21        17053
# 22        17054
# 23        17055
# 24        17056
# 25        17058
# 26        17063
# 27        17066
# 28        17067
# 29        17069
#           ...
# 41396    747763
# 41397    747766
# 41398    747768
# 41399    747769
# 41400    747772
# 41401    747774
# 41402    747776
# 41403    747777
# 41404    747778
# 41405    747783
# 41406    747789
# 41407    747792
# 41408    747796
# 41409    747798
# 41410    747799
# 41411    747802
# 41412    747805
# 41413    747818
# 41414    747820
# 41415    747822
# 41416    747826
# 41417    747827
# 41418    747828
# 41419    747840
# ...

# %%
len(cleaner_hha_df['Provider ID'].unique())
# Out:
# 11981

# %%
#take a look at cleaner csv
hhcahps_df ='../datasets/HHC_SOCRATA_HHCAHPS_PRVDR.csv'
hhcahps_df = pd.read_csv(hhcahps_df, encoding='latin-1')
hhcahps_df.head()
# Out:
#   State  CMS Certification Number (CCN)  \
# 0    AL                           17000
# 1    AL                           17009
# 2    AL                           17013
# 3    AL                           17014
# 4    AL                           17016
#
#                                        Provider Name  \
# 0  ALABAMA DEPARTMENT OF PUBLIC HEALTH HOME CARE ...
# 1  ALACARE HOME HEALTH & HOSPICE                 ...
# 2  KINDRED AT HOME                               ...
# 3  AMEDISYS HOME HEALTH                          ...
# 4  SOUTHEAST ALABAMA HOMECARE                    ...
#
#                                              Address                  City  \
# 0  201 MONROE STREET, THE RSA TOWER,  SUITE 1200 ...  MONTGOMERY
# 1  2970 LORNA ROAD                               ...  BIRMINGHAM
# 2  1239 RUCKER BLVD                              ...  ENTERPRISE
# 3  68278 MAIN STREET                             ...  BLOUNTSVILLE
# ...

# %%
hhcahps_df['CMS Certification Number (CCN)']
# Out:
# 0         17000
# 1         17009
# 2         17013
# 3         17014
# 4         17016
# 5         17018
# 6         17020
# 7         17024
# 8         17025
# 9         17026
# 10        17027
# 11        17028
# 12        17034
# 13        17035
# 14        17037
# 15        17039
# 16        17048
# 17        17050
# 18        17051
# 19        17052
# 20        17053
# 21        17054
# 22        17055
# 23        17056
# 24        17058
# 25        17063
# 26        17066
# 27        17067
# 28        17069
# 29        17070
#           ...
# 11355    747947
# 11356    747948
# 11357    747949
# 11358    747950
# 11359    747951
# 11360    747952
# 11361    747953
# 11362    747954
# 11363    747955
# 11364    747956
# 11365    747957
# 11366    747958
# 11367    747959
# 11368    747960
# 11369    747962
# 11370    747964
# 11371    747965
# 11372    747966
# 11373    747967
# 11374    747968
# 11375    747969
# 11376    747970
# 11377    747971
# 11378    747972
# ...

# %%
hhcahps_df[hhcahps_df['CMS Certification Number (CCN)']==17016]
# Out:
#   State  CMS Certification Number (CCN)  \
# 4    AL                           17016
#
#                                        Provider Name  \
# 4  SOUTHEAST ALABAMA HOMECARE                    ...
#
#                                              Address                  City  \
# 4  804 GLOVER AVENUE                             ...  ENTERPRISE
#
#      Zip       Phone Type of Ownership Offers Nursing Care Services  \
# 4  36330  3343474800             Local                          Yes
#
#   Offers Physical Therapy Services            ...              \
# 4                              Yes            ...
#
#   Star Rating for how patients rated overall care from agency  \
# 4                                                  4
#
#   Footnote for Star Rating for overall care from agency  \
# 4                                                NaN
#
#   Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# ...

# %%
#idAndOverall=
hhcahps_df[hhcahps_df['Star Rating for how patients rated overall care from agency']!='Not Available'].count()
# Out:
# State                                                                                                                              5626
# CMS Certification Number (CCN)                                                                                                     5626
# Provider Name                                                                                                                      5626
# Address                                                                                                                            5626
# City                                                                                                                               5626
# Zip                                                                                                                                5626
# Phone                                                                                                                              5626
# ...

# %%
hhcahps_df['Star Rating for how patients rated overall care from agency'].unique()
# Out:
# array(['Not Available', '4', '3', '5', '2', '1'], dtype=object)

# %%
len(hhcahps_df['CMS Certification Number (CCN)'].unique())
# Out:
# 11385

# %%
idAndOverall_df=hhcahps_df[['CMS Certification Number (CCN)','Star Rating for how patients rated overall care from agency']]

# %%
#df[df.line_race != 0]
idAllOverall_clean_df=idAndOverall_df[idAndOverall_df['Star Rating for how patients rated overall care from agency']!='Not Available']

# %%
idAllOverall_clean_df
# Out:
#        CMS Certification Number (CCN)  \
# 1                               17009
# 2                               17013
# 3                               17014
# 4                               17016
# 5                               17018
# 6                               17020
# 7                               17024
# 8                               17025
# 9                               17026
# 10                              17027
# 11                              17028
# 12                              17034
# 13                              17035
# 14                              17037
# 15                              17039
# 16                              17048
# 17                              17050
# 18                              17051
# 19                              17052
# 20                              17053
# 21                              17054
# 22                              17055
# 23                              17056
# ...

# %%
new_hh_clean_w_survey_df=pd.merge(cleaner_hha_df, idAllOverall_clean_df, left_on='Provider ID', right_on='CMS Certification Number (CCN)',how='inner')

# %%
len(new_hh_clean_w_survey_df)
# Out:
# 21508

# %%
len(cleaner_hha_df)
# Out:
# 41426

# %%
new_hh_clean_w_survey_df.to_csv('../datasets/new_hh_clean_w_survey.csv')
